# %% [markdown]
# |  GENDER     | WORLD POPULATION PERCENTAGE |
# |-------------|-----------------------------|
# | Male        |             50 %            |
# | Female      |             49.7 %          |
# | Non Binary  |             0.03 %          |

# %%
# BAR CHART FOR GENDER DISTRIBUTION IN WORLD POPULATION
import pandas as pd
import matplotlib.pyplot as plt

# data for gender distribution in the world
gender_labels = ["Male", "Female", "Non-binary"]
gender_percentage = [50, 49.7, 0.03]
Gender_population_Data=pd.DataFrame(gender_percentage,gender_labels   )
print(Gender_population_Data.head())

# bar chart
plt.bar(gender_labels, gender_percentage)
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.title("Gender Distribution in the World")
plt.show()
# Out:
#                 0
# Male        50.00
# Female      49.70
# Non-binary   0.03

# %%
# HISTOGRAM FOR GENDER DISTRIBUTION IN WORLD POPULATION
import matplotlib.pyplot as plt

# Data for gender distribution in the world
gender_labels = ["Male", "Female", "Non-binary"]
gender_percentage = [50, 49.7, 0.03]

# histogram
plt.figure(figsize=(5, 6))
plt.bar(gender_labels, gender_percentage, color=["lawngreen", "turquoise", "pink"])
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.title("Gender Distribution in the World")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# |  AGE GROUPS  |  WORLD POPULATION PERCENTAGE  |
# |--------------|-------------------------------|
# |  0-14 Age    |           25 %                |
# |  15-24 Age   |           16 %                |
# |  25-34 Age   |           20 %                |
# |  35-44 Age   |           12 %                |
# |  45-54 Age   |           9 %                 |
# |  55-64 Age   |           8 %                 |
# |  65+ Age     |           10 %                |

# %%
# AGE GROUP DISTRIBUTION IN WORLD POPULATION
import matplotlib.pyplot as plt

# data for age distribution
age_groups = ["0-14", "15-24", "25-34", "35-44", "45-54", "55-64", "65+"]
age_percentages = [25, 16, 20, 12, 9, 8, 10]

# bar chart
plt.figure(figsize=(8, 6))
plt.bar(age_groups, age_percentages, color=['royalblue', 'red', 'gray', 'lightgreen', 'gold', 'skyblue', 'orange'])
plt.xlabel("Age Groups")
plt.ylabel("Percentage of Population")
plt.title("Age Distribution of a Population")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Display the bar chart
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
plt.bar(age_groups, age_percentages, color='deepskyblue', edgecolor='black')
plt.xlabel("Age Group")
plt.ylabel("Percentage of Population")
plt.title("Distribution of Age Groups in a Population")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
